# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51060Nirnaya/Reinforcement_learning/blob/main/Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q gymnasium
import gymnasium as gym
def random_agent(environment_name):
    print("\n" + "=" * 60)
    print("ENVIRONMENT:", environment_name)
    print("=" * 60)
    env = gym.make(environment_name)
    state, info = env.reset()
    print("\nInitial State:")
    print(state)
    print("\nAction Space:")
    print(env.action_space)
    total_reward = 0
    steps = 0
    while True:
        action = env.action_space.sample()
        next_state, reward, terminated, truncated, info = env.step(action)
        print("\nStep:", steps + 1)
        print("Current State:", state)
        print("Action:", action)
        print("Reward:", reward)
        print("Next State:", next_state)


        total_reward += reward
        steps += 1


        if terminated or truncated:
            break


        state = next_state
    average_reward = total_reward / steps

    print("\n" + "-" * 60)
    print("EPISODE COMPLETED")
    print("-" * 60)

    print("Environment       :", environment_name)
    print("Total Steps       :", steps)
    print("Total Reward      :", total_reward)
    print("Average Reward    :", round(average_reward, 2))


    env.close()
random_agent("CartPole-v1")
random_agent("MountainCar-v0")
random_agent("FrozenLake-v1")
# Out:
# ...
# ENVIRONMENT: CartPole-v1
# ...
#
# Initial State:
# [ 0.00363917  0.02890428 -0.03058364 -0.00827556]
#
# Action Space:
# Discrete(2)
#
# Step: 1
# Current State: [ 0.00363917  0.02890428 -0.03058364 -0.00827556]
# Action: 0
# Reward: 1.0
# Next State: [ 0.00421725 -0.16576602 -0.03074915  0.27460313]
#
# Step: 2
# Current State: [ 0.00421725 -0.16576602 -0.03074915  0.27460313]
# Action: 1
# Reward: 1.0
# Next State: [ 0.00090193  0.02978086 -0.02525709 -0.02761734]
#
# Step: 3
# Current State: [ 0.00090193  0.02978086 -0.02525709 -0.02761734]
# Action: 1
# Reward: 1.0
# Next State: [ 0.00149755  0.22525574 -0.02580943 -0.32816094]
#
# Step: 4
# Current State: [ 0.00149755  0.22525574 -0.02580943 -0.32816094]
# Action: 1
# Reward: 1.0
# Next State: [ 0.00600266  0.42073542 -0.03237265 -0.62886995]
#
# Step: 5
# Current State: [ 0.00600266  0.42073542 -0.03237265 -0.62886995]
# Action: 1
# Reward: 1.0
# Next State: [ 0.01441737  0.61629385 -0.04495005 -0.93156976]
#
# Step: 6
# ...
